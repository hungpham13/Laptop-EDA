# %%
def main():
    import csv
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from selenium.webdriver.support.ui import WebDriverWait
    import selenium.webdriver.support.expected_conditions as EC
    from selenium.webdriver.common.by import By

    driver = webdriver.Chrome('/home/hung/Downloads/chromedriver')
    url = "https://www.thegioididong.com/laptop#pi=8"
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    result = soup.find_all('li',{'class':'item ajaxed __cate_44'})
    scraped = 0
    for item in result:
        url0 = 'https://www.thegioididong.com' + item.a.get('href') + '#top-tskt'
        driver.get(url0)
        btn = driver.find_element(By.CSS_SELECTOR,'.btn-detail.btn-short-spec').click()
        WebDriverWait(driver,timeout=5).until(EC.visibility_of_element_located((By.CSS_SELECTOR,'.parameter-all')))
        soup0 = BeautifulSoup(driver.page_source, 'html.parser')
        all =  soup0.find('div',{'class':'content-t-wrap'}).find_all('li')
        if len(all) >= 30:
            print(len(all))
        scraped += 1
        print(scraped)
    print(len(result),"scrapped:",scraped)
# main()

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
import selenium.webdriver.support.expected_conditions as EC
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome('/home/hung/Downloads/chromedriver')
# Out:
# <ipython-input-2-8dd47fe60a14>:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/hung/Downloads/chromedriver')

# %%
url = "https://www.thegioididong.com/laptop#pi=8"

driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
result = soup.find_all('li',{'class':'item ajaxed __cate_44'})
print(len(result))
# Out:
# 167

# %% [markdown]
# # Prototype

# %%
item = result[0]
title = item.a.h3.text.strip()
print(title)
# Out:
# Acer Nitro 5 Gaming AN515 57 727J i7 11800H (NH.QD9SV.005.)

# %%
url0 = 'https://www.thegioididong.com' + item.a.get('href')
driver.get(url0)
driver.find_element_by_css_selector('.btn-detail.btn-short-spec').click()
soup0 = BeautifulSoup(driver.page_source, 'html.parser')
# Out:
# <ipython-input-5-3d7a30b75a15>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('.btn-detail.btn-short-spec').click()

# %%
spec_id_to_name = {
    '28727':'cpu_name',
    '28859':'cpu_ncores',
    '28860':'cpu_nthreads',
    '93':'cpu_basefreq',
    '97':'cpu_turbofreq',
    '28861':'cpu_cache',
    
    '146':'ram_size',
    '149':'ram_type',
    '155':'ram_clock',
    '137':'ram_upgradable',
    
    '184':'storage',
    '28123':'gpu',
    '228':'battery',
    
    '187':'displ_size',
    '189':'displ_resolution',
    '29056':'displ_rate',
    '186':'displ_tech',
    '480':'displ_touchscreen',

    '196':'sound',
    '200':'ports',
    '218':'sd_card',
    '206':'wless_connect',
    '223':'webcam',
    '201':'special',
    '10741':'backlight_key',

    '7779':'weight_dims',
    '7903':'surface',
    '8599':'os',
    '22711':'launch'
}

# %%
def spec_scrap(data_id,soup0):
    '''data_id: str'''
    li = soup0.find('li',{'data-id':data_id})
    if not li:
        return ''
    ls = []
    for p in li.find_all('p',{'class':'circle'}):
        if p.text: ls.append(p.text.strip())
        else: ls.append(p.a.text.strip())
    os = "|".join(ls)
    if not os:
        try:
            os = li.span.text.strip()
        except:
            os = '|'.join(a.text.strip() for a in li.find_all('a'))
    return os

# %%
title = soup0.find('h1').text.strip()
price = soup0.find('p',{'class':'box-price-present'}).text.strip()
rating = soup0.find('p',{'class':'point'}).text.strip()
review_count = soup0.find('a',{'class':'rating-total'}).text.strip()
cmt_count = soup0.find('span',{'class':'totalcomment'}).text[:22].strip()
print(cmt_count)
# Out:
# 115 bình luận

# %% [markdown]
# # Main function

# %%
headers = ['title','price','rating','review_count','cmt_count'] + list(spec_id_to_name.values())
result = pd.DataFrame(columns = headers)
scraped = 0 #track the number of scraped laptop

url = "https://www.thegioididong.com/laptop#pi=8"
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
laptops = soup.find_all('li',{'class':'item ajaxed __cate_44'})

#for each row
for item in laptops:
    url0 = 'https://www.thegioididong.com' + item.a.get('href') + '#top-tskt'
    driver.get(url0)
    soup0 = BeautifulSoup(driver.page_source, 'html.parser')
    
    #start scraping title, price, rating, review_count, cmt_count
    title = soup0.find('h1').text.strip()
    try: price = soup0.find('p',{'class':'box-price-present'}).text.strip()
    except: price = ''
    try: rating = soup0.find('p',{'class':'point'}).text.strip()
    except: rating = ''
    try: review_count = soup0.find('a',{'class':'rating-total'}).text.strip()
    except: review_count = ''
    try: cmt_count = soup0.find('span',{'class':'totalcomment'}).text[:22].strip()
    except: cmt_count=''

    #click the button
    btn = driver.find_element(By.CSS_SELECTOR,'.btn-detail.btn-short-spec').click()
    WebDriverWait(driver,timeout=5).until(EC.visibility_of_element_located((By.CSS_SELECTOR,'.parameter-all')))
    
    #start scraping specs
    soup0 = BeautifulSoup(driver.page_source, 'html.parser')
    specs_row = [spec_scrap(id,soup0) for id in spec_id_to_name]
    
    #saved the result
    result.loc[len(result.index)] = [title,price,rating,review_count,cmt_count] + specs_row
    scraped += 1
    print(len(laptops),"scrapped:",scraped)
# Out:
# 167 scrapped: 1
# 167 scrapped: 2
# 167 scrapped: 3
# 167 scrapped: 4
# 167 scrapped: 5
# 167 scrapped: 6
# 167 scrapped: 7
# 167 scrapped: 8
# 167 scrapped: 9
# 167 scrapped: 10
# 167 scrapped: 11
# 167 scrapped: 12
# 167 scrapped: 13
# 167 scrapped: 14
# 167 scrapped: 15
# 167 scrapped: 16
# 167 scrapped: 17
# 167 scrapped: 18
# 167 scrapped: 19
# 167 scrapped: 20
# 167 scrapped: 21
# 167 scrapped: 22
# 167 scrapped: 23
# 167 scrapped: 24
# 167 scrapped: 25
# 167 scrapped: 26
# 167 scrapped: 27
# 167 scrapped: 28
# 167 scrapped: 29
# 167 scrapped: 30
# 167 scrapped: 31
# 167 scrapped: 32
# 167 scrapped: 33
# 167 scrapped: 34
# 167 scrapped: 35
# 167 scrapped: 36
# 167 scrapped: 37
# 167 scrapped: 38
# 167 scrapped: 39
# 167 scrapped: 40
# 167 scrapped: 41
# 167 scrapped: 42
# 167 scrapped: 43
# 167 scrapped: 44
# 167 scrapped: 45
# 167 scrapped: 46
# 167 scrapped: 47
# 167 scrapped: 48
# 167 scrapped: 49
# 167 scrapped: 50
# 167 scrapped: 51
# 167 scrapped: 52
# 167 scrapped: 53
# 167 scrapped: 54
# 167 scrapped: 55
# 167 scrapped: 56
# 167 scrapped: 57
# 167 scrapped: 58
# 167 scrapped: 59
# 167 scrapped: 60
# 167 scrapped: 61
# 167 scrapped: 62
# 167 scrapped: 63
# 167 scrapped: 64
# 167 scrapped: 65
# 167 scrapped: 66
# 167 scrapped: 67
# 167 scrapped: 68
# 167 scrapped: 69
# 167 scrapped: 70
# 167 scrapped: 71
# 167 scrapped: 72
# 167 scrapped: 73
# 167 scrapped: 74
# 167 scrapped: 75
# 167 scrapped: 76
# 167 scrapped: 77
# 167 scrapped: 78
# 167 scrapped: 79
# 167 scrapped: 80
# 167 scrapped: 81
# 167 scrapped: 82
# 167 scrapped: 83
# 167 scrapped: 84
# 167 scrapped: 85
# 167 scrapped: 86
# 167 scrapped: 87
# 167 scrapped: 88
# 167 scrapped: 89
# 167 scrapped: 90
# 167 scrapped: 91
# 167 scrapped: 92
# 167 scrapped: 93
# 167 scrapped: 94
# 167 scrapped: 95
# 167 scrapped: 96
# 167 scrapped: 97
# 167 scrapped: 98
# 167 scrapped: 99
# 167 scrapped: 100
# 167 scrapped: 101
# 167 scrapped: 102
# 167 scrapped: 103
# 167 scrapped: 104
# 167 scrapped: 105
# 167 scrapped: 106
# 167 scrapped: 107
# 167 scrapped: 108
# 167 scrapped: 109
# 167 scrapped: 110
# 167 scrapped: 111
# 167 scrapped: 112
# 167 scrapped: 113
# 167 scrapped: 114
# 167 scrapped: 115
# 167 scrapped: 116
# 167 scrapped: 117
# 167 scrapped: 118
# 167 scrapped: 119
# 167 scrapped: 120
# 167 scrapped: 121
# 167 scrapped: 122
# 167 scrapped: 123
# 167 scrapped: 124
# 167 scrapped: 125
# 167 scrapped: 126
# 167 scrapped: 127
# 167 scrapped: 128
# 167 scrapped: 129
# 167 scrapped: 130
# 167 scrapped: 131
# 167 scrapped: 132
# 167 scrapped: 133
# 167 scrapped: 134
# 167 scrapped: 135
# 167 scrapped: 136
# 167 scrapped: 137
# 167 scrapped: 138
# 167 scrapped: 139
# 167 scrapped: 140
# 167 scrapped: 141
# 167 scrapped: 142
# 167 scrapped: 143
# 167 scrapped: 144
# 167 scrapped: 145
# 167 scrapped: 146
# 167 scrapped: 147
# 167 scrapped: 148
# 167 scrapped: 149
# 167 scrapped: 150
# 167 scrapped: 151
# 167 scrapped: 152
# 167 scrapped: 153
# 167 scrapped: 154
# 167 scrapped: 155
# 167 scrapped: 156
# 167 scrapped: 157
# 167 scrapped: 158
# 167 scrapped: 159
# 167 scrapped: 160
# 167 scrapped: 161
# 167 scrapped: 162
# 167 scrapped: 163
# 167 scrapped: 164
# 167 scrapped: 165
# 167 scrapped: 166
# 167 scrapped: 167

# %%
pd.set_option('display.max_columns', 34)
result.head()
# Out:
#                                                title          price rating  \
# 0  Laptop Acer Nitro 5 Gaming AN515 57 727J i7 11...  28.990.000₫ *    4.7
# 1  Laptop MSI Gaming GF65 Thin 10UE i5 10500H/16G...    29.090.000₫      5
# 2  Laptop Apple MacBook Pro M1 2020 16GB/512GB (Z...    44.990.000₫    4.7
# 3  Laptop Acer Nitro 5 Gaming AN515 57 5831 i5 11...  31.990.000₫ *
# 4  Laptop Acer Nitro 5 Gaming AN515 57 54AF i5 11...  27.990.000₫ *      5
#
#   review_count      cmt_count                           cpu_name cpu_ncores  \
# 0   5 đánh giá  115 bình luận  Intel Core i7 Tiger Lake - 11800H          8
# 1   2 đánh giá   27 bình luận  Intel Core i5 Comet Lake - 10500H          6
# 2  17 đánh giá  195 bình luận                           Apple M1
# 3                90 bình luận  Intel Core i5 Tiger Lake - 11400H          6
# 4   1 đánh giá   38 bình luận  Intel Core i5 Tiger Lake - 11400H          6
#
#   cpu_nthreads cpu_basefreq        cpu_turbofreq cpu_cache ram_size  \
# 0           16     2.30 GHz  Turbo Boost 4.6 GHz     24 MB     8 GB
# 1           12     2.50 GHz  Turbo Boost 4.5 GHz     12 MB
# 2                                                             16 GB
# 3           12     2.70 GHz  Turbo Boost 4.5 GHz     12 MB     8 GB
# 4           12     2.70 GHz  Turbo Boost 4.5 GHz     12 MB    16 GB
#
#                              ram_type ram_clock         ram_upgradable  \
# 0  DDR4 2 khe (1 khe 8GB + 1 khe rời)  3200 MHz                  32 GB
# 1  DDR4 2 khe (1 khe 8GB + 1 khe 8GB)  3200 MHz                  64 GB
# 2                                                Không hỗ trợ nâng cấp
# 3  DDR4 2 khe (1 khe 8GB + 1 khe rời)  3200 MHz                  32 GB
# 4  DDR4 2 khe (1 khe 8GB + 1 khe 8GB)  3200 MHz                  32 GB
#
#                                              storage  \
# 0  Hỗ trợ khe cắm HDD SATA (nâng cấp tối đa 2TB),...
# 1  Hỗ trợ thêm 1 khe cắm SSD M.2 PCIe mở rộng (nâ...
# 2                                         512 GB SSD
# 3  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...
# 4  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...
#
#                                               gpu               battery  \
# 0       Card rời - NVIDIA GeForce RTX3050Ti, 4 GB  4-cell Li-ion, 57 Wh
# 1  Card rời - NVIDIA GeForce RTX 3060 Max-Q, 6 GB  3-cell Li-ion, 51 Wh
# 2                      Card tích hợp - 8 nhân GPU       Khoảng 10 tiếng
# 3        Card rời - NVIDIA GeForce RTX 3060, 6 GB  4-cell Li-ion, 57 Wh
# 4         Card rời - NVIDIA GeForce RTX3050, 4 GB  4-cell Li-ion, 57 Wh
#
#   displ_size       displ_resolution displ_rate  \
# 0  15.6 inch  Full HD (1920 x 1080)     144 Hz
# 1  15.6 inch  Full HD (1920 x 1080)     144 Hz
# 2  13.3 inch   Retina (2560 x 1600)
# 3  15.6 inch  Full HD (1920 x 1080)     144 Hz
# 4  15.6 inch  Full HD (1920 x 1080)     144 Hz
#
#                                           displ_tech displ_touchscreen  \
# 0           Acer ComfyView, LED Backlit, Tấm nền IPS
# 1                 Chống chói Anti Glare, Tấm nền IPS
# 2  500 nits brightness, LED Backlit, Retina, True...
# 3           Tấm nền IPS, LED Backlit, Acer ComfyView
# 4           Acer ComfyView, LED Backlit, Tấm nền IPS
#
#                                           sound  \
# 0           Acer TrueHarmony, DTS X:Ultra Audio
# 1  Nahimic Audio, Realtek High Definition Audio
# 2  3 microphones, Dolby Atmos, Loa kép (2 kênh)
# 3           Acer TrueHarmony, DTS X:Ultra Audio
# 4           Acer TrueHarmony, DTS X:Ultra Audio
#
#                                                ports sd_card  \
# 0  3 x USB 3.2, HDMI, Jack tai nghe 3.5 mm, LAN (...
# 1  2 x USB 3.2, 2 x USB Type-C, HDMI, Jack tai ng...
# 2    2 x Thunderbolt 3 (USB-C), Jack tai nghe 3.5 mm
# 3  Jack tai nghe 3.5 mm, 3 x USB 3.2, HDMI, LAN (...
# 4  3 x USB 3.2, HDMI, Jack tai nghe 3.5 mm, LAN (...
#
#                        wless_connect     webcam                      special  \
# 0  Bluetooth 5.1, Wi-Fi 6 (802.11ax)  HD webcam  Đèn bàn phím chuyển màu RGB
# 1  Bluetooth 5.1, Wi-Fi 6 (802.11ax)  HD webcam
# 2  Bluetooth 5.0, Wi-Fi 6 (802.11ax)  HD webcam              Bảo mật vân tay
# 3  Wi-Fi 6 (802.11ax), Bluetooth 5.1  HD webcam  Đèn bàn phím chuyển màu RGB
# 4  Bluetooth 5.1, Wi-Fi 6 (802.11ax)  HD webcam  Đèn bàn phím chuyển màu RGB
#
#   backlight_key                                        weight_dims  \
# 0            Có  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...
# 1            Có  Dài 359 mm - Rộng 254 mm - Dày 21.7 mm - Nặng ...
# 2            Có  Dài 304.1 mm - Rộng 212.4 mm - Dày 15.6 mm - N...
# 3            Có  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...
# 4            Có  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...
#
#                    surface                  os launch
# 0                  Vỏ nhựa  Windows 10 Home SL   2021
# 1                  Vỏ nhựa  Windows 10 Home SL   2021
# 2  Vỏ kim loại nguyên khối              Mac OS   2020
# 3                  Vỏ nhựa  Windows 10 Home SL   2021
# 4                  Vỏ nhựa  Windows 11 Home SL   2021

# %%
result.to_csv('thegioididong.csv',encoding='utf-8')
