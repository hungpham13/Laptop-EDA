# %%
import pandas as pd

# %%
data = pd.read_csv('./result_detail_final.csv', index_col = False)
data.head()
# Out:
#              PN  rating  rating_count  comment_count  \
# 0  NH.QD9SV.001     5.0           1.0          598.0
# 1         852VN     5.0           1.0          340.0
# 2      P112F001     5.0           1.0          116.0
# 3      V5I3001W     5.0           2.0          788.0
# 4    82H80040VN     5.0           4.0          378.0
#
#                                          name     price  \
# 0   Acer Nitro Gaming AN515-57-74NU/i7-11800H  28499000
# 1  MSI Modern 14 B11MOU 852VN i5 1155G7/852VN  18799000
# 2   Dell Inspiron N3511 i3 1115G4/P112F001ABL  15299000
# 3                 Dell Vostro V3500 i3 1115G4  15599000
# 4      Lenovo IdeaPad Slim 3 15ITL6 i3 1115G4  14999000
#
#                       CPU   RAM RAM_upgradable                            GPU  \
# 0  Intel Core i7 - 11800H  8 GB            Yes  NVIDIA GeForce RTX 3050Ti 4GB
# 1  Intel Core i5 - 1155G7  8 GB            Yes         Intel Iris Xe Graphics
# 2  Intel Core i3 - 1115G4  4 GB            Yes             Intel UHD Graphics
# 3  Intel Core i3 - 1115G4  8 GB            Yes             Intel UHD Graphics
# 4  Intel Core i3 - 1115G4  8 GB            Yes             Intel UHD Graphics
#
#    ...          OS surface_material release_year hdmi jack  lan type_c  usb  \
# 0  ...  Windows 10             Nhựa         2021  Yes  Yes  Yes    Yes  Yes
# 1  ...  Windows 10         Kim Loại         2021  Yes  Yes  Yes    Yes  Yes
# 2  ...  Windows 10             Nhựa         2021  Yes  Yes  Yes    Yes  Yes
# 3  ...  Windows 10             Nhựa         2021  Yes  Yes  Yes    Yes  Yes
# 4  ...  Windows 10      ABS plastic         2021  Yes  Yes  Yes    Yes  Yes
#
#     sd keyboard_light
# 0   No            Yes
# 1  Yes            Yes
# 2  Yes            Yes
# 3  Yes            Yes
# 4  Yes            Yes
#
# [5 rows x 31 columns]

# %%
data[['Brand', 'Series']] = data.name.str.split(n = 1, expand=True)
data = data.drop('name', 1)
data.head()
# Out:
#              PN  rating  rating_count  comment_count     price  \
# 0  NH.QD9SV.001     5.0           1.0          598.0  28499000
# 1         852VN     5.0           1.0          340.0  18799000
# 2      P112F001     5.0           1.0          116.0  15299000
# 3      V5I3001W     5.0           2.0          788.0  15599000
# 4    82H80040VN     5.0           4.0          378.0  14999000
#
#                       CPU   RAM RAM_upgradable                            GPU  \
# 0  Intel Core i7 - 11800H  8 GB            Yes  NVIDIA GeForce RTX 3050Ti 4GB
# 1  Intel Core i5 - 1155G7  8 GB            Yes         Intel Iris Xe Graphics
# 2  Intel Core i3 - 1115G4  4 GB            Yes             Intel UHD Graphics
# 3  Intel Core i3 - 1115G4  8 GB            Yes             Intel UHD Graphics
# 4  Intel Core i3 - 1115G4  8 GB            Yes             Intel UHD Graphics
#
#   battery_wh  ... release_year hdmi jack  lan type_c  usb   sd keyboard_light  \
# 0         --  ...         2021  Yes  Yes  Yes    Yes  Yes   No            Yes
# 1       65 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 2       65 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 3       45 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 4         --  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
#
#     Brand                                  Series
# 0    Acer    Nitro Gaming AN515-57-74NU/i7-11800H
# 1     MSI  Modern 14 B11MOU 852VN i5 1155G7/852VN
# 2    Dell    Inspiron N3511 i3 1115G4/P112F001ABL
# 3    Dell                  Vostro V3500 i3 1115G4
# 4  Lenovo         IdeaPad Slim 3 15ITL6 i3 1115G4
#
# [5 rows x 32 columns]

# %%
data['RAM'] = data['RAM'].str.split(' ', 1).str[0]
data.head()
# Out:
#              PN  rating  rating_count  comment_count     price  \
# 0  NH.QD9SV.001     5.0           1.0          598.0  28499000
# 1         852VN     5.0           1.0          340.0  18799000
# 2      P112F001     5.0           1.0          116.0  15299000
# 3      V5I3001W     5.0           2.0          788.0  15599000
# 4    82H80040VN     5.0           4.0          378.0  14999000
#
#                       CPU RAM RAM_upgradable                            GPU  \
# 0  Intel Core i7 - 11800H   8            Yes  NVIDIA GeForce RTX 3050Ti 4GB
# 1  Intel Core i5 - 1155G7   8            Yes         Intel Iris Xe Graphics
# 2  Intel Core i3 - 1115G4   4            Yes             Intel UHD Graphics
# 3  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
# 4  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
#
#   battery_wh  ... release_year hdmi jack  lan type_c  usb   sd keyboard_light  \
# 0         --  ...         2021  Yes  Yes  Yes    Yes  Yes   No            Yes
# 1       65 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 2       65 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 3       45 W  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
# 4         --  ...         2021  Yes  Yes  Yes    Yes  Yes  Yes            Yes
#
#     Brand                                  Series
# 0    Acer    Nitro Gaming AN515-57-74NU/i7-11800H
# 1     MSI  Modern 14 B11MOU 852VN i5 1155G7/852VN
# 2    Dell    Inspiron N3511 i3 1115G4/P112F001ABL
# 3    Dell                  Vostro V3500 i3 1115G4
# 4  Lenovo         IdeaPad Slim 3 15ITL6 i3 1115G4
#
# [5 rows x 32 columns]

# %%
data[['storage_type', 'storage_size']] = data['hard_drive'].str.split(' ', n = 1, expand = True)
data = data.drop('hard_drive', 1)
data.head()
# Out:
#              PN  rating  rating_count  comment_count     price  \
# 0  NH.QD9SV.001     5.0           1.0          598.0  28499000
# 1         852VN     5.0           1.0          340.0  18799000
# 2      P112F001     5.0           1.0          116.0  15299000
# 3      V5I3001W     5.0           2.0          788.0  15599000
# 4    82H80040VN     5.0           4.0          378.0  14999000
#
#                       CPU RAM RAM_upgradable                            GPU  \
# 0  Intel Core i7 - 11800H   8            Yes  NVIDIA GeForce RTX 3050Ti 4GB
# 1  Intel Core i5 - 1155G7   8            Yes         Intel Iris Xe Graphics
# 2  Intel Core i3 - 1115G4   4            Yes             Intel UHD Graphics
# 3  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
# 4  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
#
#   battery_wh  ... jack  lan type_c  usb   sd keyboard_light   Brand  \
# 0         --  ...  Yes  Yes    Yes  Yes   No            Yes    Acer
# 1       65 W  ...  Yes  Yes    Yes  Yes  Yes            Yes     MSI
# 2       65 W  ...  Yes  Yes    Yes  Yes  Yes            Yes    Dell
# 3       45 W  ...  Yes  Yes    Yes  Yes  Yes            Yes    Dell
# 4         --  ...  Yes  Yes    Yes  Yes  Yes            Yes  Lenovo
#
#                                    Series storage_type storage_size
# 0    Nitro Gaming AN515-57-74NU/i7-11800H          SSD       512 GB
# 1  Modern 14 B11MOU 852VN i5 1155G7/852VN          SSD       512 GB
# 2    Inspiron N3511 i3 1115G4/P112F001ABL          SSD       256 GB
# 3                  Vostro V3500 i3 1115G4          SSD       256 GB
# 4         IdeaPad Slim 3 15ITL6 i3 1115G4          SSD       512 GB
#
# [5 rows x 33 columns]

# %%
data['storage_size'] = data['storage_size'].str.extract('(\d+)')
data['storage_size']
# Out:
# 0      512
# 1      512
# 2      256
# 3      256
# 4      512
#       ...
# 141    256
# 142    128
# 143    128
# 144    128
# 145    128
# Name: storage_size, Length: 146, dtype: object

# %%
data['screen_size'] = data['screen_size'].str.strip('"')
data['screen_size']
# Out:
# 0      15.6
# 1      14.0
# 2      15.6
# 3      15.6
# 4      15.6
#        ...
# 141    15.6
# 142    15.6
# 143    15.6
# 144    11.6
# 145    11.6
# Name: screen_size, Length: 146, dtype: object

# %%
data['display_resolution'] = data['display_resolution'].str.split(' ', n = 3).str[0:3].str.join(' ')
data['display_resolution']
# Out:
# 0      1920 x 1080
# 1      1920 x 1080
# 2      1920 x 1080
# 3      1920 x 1080
# 4      1920 x 1080
#           ...
# 141    1920 x 1080
# 142     1366 x 768
# 143     1366 x 768
# 144     1366 x 768
# 145     1366 x 768
# Name: display_resolution, Length: 146, dtype: object

# %%
data['display_rating'] = data['display_rating'].str.split(' ', 1).str[0]
data['display_rating']
# Out:
# 0      144
# 1       60
# 2       60
# 3       60
# 4       60
#       ...
# 141     60
# 142     60
# 143     60
# 144     60
# 145     --
# Name: display_rating, Length: 146, dtype: object

# %%
data[['cpu_brand', 'cpu_code']] = data['CPU'].str.split('-', n = 1, expand = True)
data.head()
# Out:
#              PN  rating  rating_count  comment_count     price  \
# 0  NH.QD9SV.001     5.0           1.0          598.0  28499000
# 1         852VN     5.0           1.0          340.0  18799000
# 2      P112F001     5.0           1.0          116.0  15299000
# 3      V5I3001W     5.0           2.0          788.0  15599000
# 4    82H80040VN     5.0           4.0          378.0  14999000
#
#                       CPU RAM RAM_upgradable                            GPU  \
# 0  Intel Core i7 - 11800H   8            Yes  NVIDIA GeForce RTX 3050Ti 4GB
# 1  Intel Core i5 - 1155G7   8            Yes         Intel Iris Xe Graphics
# 2  Intel Core i3 - 1115G4   4            Yes             Intel UHD Graphics
# 3  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
# 4  Intel Core i3 - 1115G4   8            Yes             Intel UHD Graphics
#
#   battery_wh  ... type_c  usb   sd keyboard_light   Brand  \
# 0         --  ...    Yes  Yes   No            Yes    Acer
# 1       65 W  ...    Yes  Yes  Yes            Yes     MSI
# 2       65 W  ...    Yes  Yes  Yes            Yes    Dell
# 3       45 W  ...    Yes  Yes  Yes            Yes    Dell
# 4         --  ...    Yes  Yes  Yes            Yes  Lenovo
#
#                                    Series storage_type storage_size  \
# 0    Nitro Gaming AN515-57-74NU/i7-11800H          SSD          512
# 1  Modern 14 B11MOU 852VN i5 1155G7/852VN          SSD          512
# 2    Inspiron N3511 i3 1115G4/P112F001ABL          SSD          256
# 3                  Vostro V3500 i3 1115G4          SSD          256
# 4         IdeaPad Slim 3 15ITL6 i3 1115G4          SSD          512
#
#         cpu_brand cpu_code
# 0  Intel Core i7    11800H
# 1  Intel Core i5    1155G7
# 2  Intel Core i3    1115G4
# 3  Intel Core i3    1115G4
# 4  Intel Core i3    1115G4
#
# [5 rows x 35 columns]

# %%
for row, brand in enumerate(data.loc[:,'cpu_brand']):
    try:
        list = brand.split(' ', 1)
        if 'apple' in brand.lower():
            data.at[row, 'cpu_brand'] = list[0]
            data.at[row, 'cpu_code'] = list[1]
        else: 
            data.at[row, 'cpu_brand'] = list[0]
    except: 
        continue
data['cpu_brand']
# Out:
# 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 141    Intel
# 142    Intel
# 143    Intel
# 144    Intel
# 145    Intel
# Name: cpu_brand, Length: 146, dtype: object

# %%
cols = data.columns.tolist()
print(cols)
# Out:
# ['PN', 'rating', 'rating_count', 'comment_count', 'price', 'CPU', 'RAM', 'RAM_upgradable', 'GPU', 'battery_wh', 'storage_upgradable', 'screen_size', 'display_resolution', 'display_rating', 'screen_technology', 'weight', 'length', 'width', 'height', 'OS', 'surface_material', 'release_year', 'hdmi', 'jack', 'lan', 'type_c', 'usb', 'sd', 'keyboard_light', 'Brand', 'Series', 'storage_type', 'storage_size', 'cpu_brand', 'cpu_code']

# %%
cols  = ['PN', 'rating', 'rating_count','comment_count' ,'Brand', 'Series','price', 'cpu_brand', 'cpu_code',
         'RAM', 'RAM_upgradable', 'GPU', 'battery_wh', 'storage_type', 'storage_size',
         'storage_upgradable', 'screen_size', 'display_resolution', 'display_rating', 'screen_technology', 
         'weight', 'length', 'width', 'height', 'OS', 'surface_material', 'release_year', 
        'hdmi', 'jack', 'lan', 'type_c', 'usb', 'sd', 'keyboard_light']
data = data.reindex(columns = cols)
data.iloc[0,:]
# Out:
# PN                                            NH.QD9SV.001
# rating                                                 5.0
# rating_count                                           1.0
# comment_count                                        598.0
# Brand                                                 Acer
# Series                Nitro Gaming AN515-57-74NU/i7-11800H
# price                                             28499000
# cpu_brand                                            Intel
# cpu_code                                            11800H
# RAM                                                      8
# RAM_upgradable                                         Yes
# GPU                          NVIDIA GeForce RTX 3050Ti 4GB
# battery_wh                                              --
# storage_type                                           SSD
# storage_size                                           512
# storage_upgradable                                     Yes
# screen_size                                           15.6
# display_resolution                             1920 x 1080
# display_rating                                         144
# screen_technology                              LED-backlit
# weight                                                 2.2
# length                                               363.4
# width                                                  255
# height                                                23.9
# OS                                              Windows 10
# surface_material                                      Nhựa
# release_year                                          2021
# hdmi                                                   Yes
# jack                                                   Yes
# lan                                                    Yes
# type_c                                                 Yes
# usb                                                    Yes
# sd                                                      No
# keyboard_light                                         Yes
# Name: 0, dtype: object

# %%
data.Series
# Out:
# 0        Nitro Gaming AN515-57-74NU/i7-11800H
# 1      Modern 14 B11MOU 852VN i5 1155G7/852VN
# 2        Inspiron N3511 i3 1115G4/P112F001ABL
# 3                      Vostro V3500 i3 1115G4
# 4             IdeaPad Slim 3 15ITL6 i3 1115G4
#                         ...
# 141         Vivobook A515EA-BN1688T/i3-1115G4
# 142           Inspiron N3502 Pentium N5030/NK
# 143             Inspiron N3510 N4020/P91K5_NK
# 144              Flip BR1100FKA-BP0531T/N4500
# 145              Vivobook E210KA-GJ031T/N4500
# Name: Series, Length: 146, dtype: object

# %%
data.to_csv('fpt_result_cleaned.csv', index = False)

# %%
df = pd.read_csv('./fpt_result_cleaned.csv')
df.head()
# Out:
#              PN  rating  rating_count  comment_count   Brand  \
# 0  NH.QD9SV.001     5.0           1.0          598.0    Acer
# 1         852VN     5.0           1.0          340.0     MSI
# 2      P112F001     5.0           1.0          116.0    Dell
# 3      V5I3001W     5.0           2.0          788.0    Dell
# 4    82H80040VN     5.0           4.0          378.0  Lenovo
#
#                                    Series     price cpu_brand cpu_code RAM  \
# 0    Nitro Gaming AN515-57-74NU/i7-11800H  28499000     Intel   11800H   8
# 1  Modern 14 B11MOU 852VN i5 1155G7/852VN  18799000     Intel   1155G7   8
# 2    Inspiron N3511 i3 1115G4/P112F001ABL  15299000     Intel   1115G4   4
# 3                  Vostro V3500 i3 1115G4  15599000     Intel   1115G4   8
# 4         IdeaPad Slim 3 15ITL6 i3 1115G4  14999000     Intel   1115G4   8
#
#    ...          OS surface_material release_year hdmi  jack  lan  type_c  usb  \
# 0  ...  Windows 10             Nhựa         2021  Yes   Yes  Yes     Yes  Yes
# 1  ...  Windows 10         Kim Loại         2021  Yes   Yes  Yes     Yes  Yes
# 2  ...  Windows 10             Nhựa         2021  Yes   Yes  Yes     Yes  Yes
# 3  ...  Windows 10             Nhựa         2021  Yes   Yes  Yes     Yes  Yes
# 4  ...  Windows 10      ABS plastic         2021  Yes   Yes  Yes     Yes  Yes
#
#     sd keyboard_light
# 0   No            Yes
# 1  Yes            Yes
# 2  Yes            Yes
# 3  Yes            Yes
# 4  Yes            Yes
#
# [5 rows x 34 columns]
